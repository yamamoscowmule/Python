# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("train.csv",sep = ",")

# %%
df.head(100)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
df.drop(["Name"],axis=1,inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Pclass     Sex   Age  SibSp  Parch   Ticket     Fare Cabin  \
# 0          892       3    male  34.5      0      0   330911   7.8292   NaN
# 1          893       3  female  47.0      1      0   363272   7.0000   NaN
# 2          894       2    male  62.0      0      0   240276   9.6875   NaN
# 3          895       3    male  27.0      0      0   315154   8.6625   NaN
# 4          896       3  female  22.0      1      1  3101298  12.2875   NaN
#
#   Embarked
# 0        Q
# 1        S
# 2        Q
# 3        S
# 4        S

# %%
df.drop(["PassengerId","Ticket","Cabin","Embarked"],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Pclass     Sex   Age  SibSp  Parch     Fare
# 0       3    male  34.5      0      0   7.8292
# 1       3  female  47.0      1      0   7.0000
# 2       2    male  62.0      0      0   9.6875
# 3       3    male  27.0      0      0   8.6625
# 4       3  female  22.0      1      1  12.2875

# %%
df.isnull().sum()
# Out:
# Pclass     0
# Sex        0
# Age       86
# SibSp      0
# Parch      0
# Fare       1
# dtype: int64

# %%
age_mean = df.Age.mean()
df.fillna(value = {"Age":age_mean},inplace = True)

# %%
df.isnull().sum()
# Out:
# Pclass    0
# Sex       0
# Age       0
# SibSp     0
# Parch     0
# Fare      1
# dtype: int64

# %%
df.dtypes
# Out:
# Pclass      int64
# Sex        object
# Age       float64
# SibSp       int64
# Parch       int64
# Fare      float64
# dtype: object

# %%
df["Sex"][df["Sex"] == "male"] =0
df["Sex"][df["Sex"] == "female"] =1

df["Sex"] = df["Sex"].astype("int64",inplace = True)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df.dtypes
# Out:
# Pclass      int64
# Sex         int64
# Age       float64
# SibSp       int64
# Parch       int64
# Fare      float64
# dtype: object

# %%
df.head(100)
# Out:
#     Pclass  Sex       Age  SibSp  Parch      Fare
# 0        3    0  34.50000      0      0    7.8292
# 1        3    1  47.00000      1      0    7.0000
# 2        2    0  62.00000      0      0    9.6875
# 3        3    0  27.00000      0      0    8.6625
# 4        3    1  22.00000      1      1   12.2875
# 5        3    0  14.00000      0      0    9.2250
# 6        3    1  30.00000      0      0    7.6292
# 7        2    0  26.00000      1      1   29.0000
# 8        3    1  18.00000      0      0    7.2292
# 9        3    0  21.00000      2      0   24.1500
# 10       3    0  30.27259      0      0    7.8958
# 11       1    0  46.00000      0      0   26.0000
# 12       1    1  23.00000      1      0   82.2667
# 13       2    0  63.00000      1      0   26.0000
# 14       1    1  47.00000      1      0   61.1750
# 15       2    1  24.00000      1      0   27.7208
# 16       2    0  35.00000      0      0   12.3500
# 17       3    0  21.00000      0      0    7.2250
# ...

# %%
df.describe()
# Out:
#            Pclass         Sex         Age       SibSp       Parch        Fare
# count  418.000000  418.000000  418.000000  418.000000  418.000000  417.000000
# mean     2.265550    0.363636   30.272590    0.447368    0.392344   35.627188
# std      0.841838    0.481622   12.634534    0.896760    0.981429   55.907576
# min      1.000000    0.000000    0.170000    0.000000    0.000000    0.000000
# 25%      1.000000    0.000000   23.000000    0.000000    0.000000    7.895800
# 50%      3.000000    0.000000   30.272590    0.000000    0.000000   14.454200
# 75%      3.000000    1.000000   35.750000    1.000000    0.000000   31.500000
# max      3.000000    1.000000   76.000000    8.000000    9.000000  512.329200

# %%
df.to_csv("test_reshape.csv",index=False)

# %%
train_data = train.values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-eece407d16d5> in <module>
# ----> 1 train_data = train.values
#
# NameError: name 'train' is not defined
